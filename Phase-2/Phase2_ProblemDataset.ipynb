# %% [markdown]
# <a href="https://colab.research.google.com/github/meherajmithun/CPVision-AI/blob/main/Phase-2/Phase2_ProblemDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("raw_dataset.csv") #Read the CSV file into a Pandas DataFrame.

# %%
df.head()
df.info()
print(df.columns)

df = df[
    [
        "problem_id",
        "problem_idx",
        "problem_name",
        "problem_statement",
        "problem_tags",
        "problem_dificulty"
    ]
]
df.head()
# [
# 'constructive algorithms',
# 'greedy',
# 'math'
# ]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7185 entries, 0 to 7184
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   problem_id         7185 non-null   int64
#  1   problem_idx        7185 non-null   object
#  2   problem_name       7185 non-null   object
#  3   problem_statement  7185 non-null   object
#  4   problem_tags       7185 non-null   object
#  5   problem_dificulty  7185 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 336.9+ KB
# Index(['problem_id', 'problem_idx', 'problem_name', 'problem_statement',
#        'problem_tags', 'problem_dificulty'],
#       dtype='object')
# ['constructive algorithms', 'greedy', 'math']

# %% [markdown]
# Now your dataset looks like
# Column	Purpose
# problem_id	Identification
# problem_idx	Identification
# problem_name	Optional Feature
# problem_statement	Input
# problem_tags	Target
# problem_dificulty	Target
#
# This is a clean ML dataset.

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# problem_id           0
# problem_idx          0
# problem_name         0
# problem_statement    0
# problem_tags         0
# problem_dificulty    0
# dtype: int64

# %%
# Check duplicate rows
print(df.duplicated().sum())
# Out:
# 0

# %%
# Unique difficulty levels
print(sorted(df["rating"].unique()))
# Number of problems for each difficulty
difficulty_counts = df["rating"].value_counts().sort_index()
print(difficulty_counts)

# print(df.columns)
# Out:
# [np.int64(800), np.int64(900), np.int64(1000), np.int64(1100), np.int64(1200), np.int64(1300), np.int64(1400), np.int64(1500), np.int64(1600), np.int64(1700), np.int64(1800), np.int64(1900), np.int64(2000), np.int64(2100), np.int64(2200), np.int64(2300), np.int64(2400), np.int64(2500), np.int64(2600), np.int64(2700), np.int64(2800), np.int64(2900), np.int64(3000), np.int64(3100), np.int64(3200), np.int64(3300), np.int64(3400), np.int64(3500)]
# rating
# 800     759
# 900     252
# 1000    281
# 1100    314
# 1200    328
# 1300    327
# 1400    301
# 1500    329
# 1600    364
# 1700    353
# 1800    302
# 1900    361
# 2000    318
# 2100    288
# 2200    297
# 2300    260
# 2400    301
# 2500    269
# 2600    200
# 2700    194
# 2800    140
# 2900    137
# 3000    109
# 3100     90
# 3200     77
# 3300     71
# 3400     56
# 3500    107
# Name: count, dtype: int64

# %%
df.to_csv("cpvision_dataset.csv", index=False) # save it for next 3 phases use

# %%
# Save cleaned dataset
df.to_csv("cpvision_dataset.csv", index=False)

print("Dataset saved successfully!")

# %%
#verify
import os

print(os.listdir())
# Out:
# ['.config', 'cpvision_dataset.csv', 'raw_dataset.csv', 'sample_data']
